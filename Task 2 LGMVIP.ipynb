# %% [markdown]
# # Data Science Inten at  LetsGrowMore Virtual Intenship Program
#                                   October 2021 Batch
#
# # Author : Janhavi Chandak
#
# # Level : Begineer
#
# # Task   2  : Image to Pencil Sketch
#
# Description of Task :
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image.
#
# Reference Link : https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python/

# %% [markdown]
# # Import Modules

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Orignal Image to display :

# %%
#showing Image:
orignal_image = cv2.imread("kitkat.jpg")
orignal_image = cv2.cvtColor(orignal_image,cv2.COLOR_BGR2RGB)
cv2.imshow("oignal_image",orignal_image)

# %%
plt.imshow(orignal_image)

# %% [markdown]
# # After converting it into a grayscale image

# %%
#to convert bgr to gray colour:
gray_image = cv2.cvtColor(orignal_image,cv2.COLOR_BGR2GRAY)
gray_image = cv2.cvtColor(gray_image,cv2.COLOR_BGR2RGB)
cv2.imshow("gray_img",gray_image)

# cv2.waitKey(0)

# %%
plt.imshow(gray_image)

# %% [markdown]
# # Inverting the grayscale image also called negative image:

# %%
#invert the new grayscale image:
inverted_image = 255 - gray_image
inverted_image = cv2.cvtColor(inverted_image,cv2.COLOR_BGR2RGB)
cv2.imshow("inverted_img",inverted_image)
# cv2.waitKey()

# %%
plt.imshow(inverted_image)

# %% [markdown]
# # pencil sketch by mixing the grayscale image with the inverted blurry image:

# %%
#blur image:
blurred = cv2.GaussianBlur(inverted_image,(21,21),0)

# %%
#final step - to invert blurred image,then we can easily convert the image into pencil sketch:
inverted_burred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_burred, scale = 256.0)
pencil_sketch = cv2.cvtColor(pencil_sketch,cv2.COLOR_BGR2RGB)
cv2.imshow("pencil_sketch",pencil_sketch)

# %%
plt.imshow(pencil_sketch)

# %% [markdown]
# ## ORIGNAL IMAGE >> PENCIL SKETCH IMAGE:

# %%
plt.imshow(orignal_image)

# %%
plt.imshow(pencil_sketch)

# %% [markdown]
# #                                               THANK YOU!
